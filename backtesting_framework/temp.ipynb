# %%
# from data.loader import DataLoader
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import datetime
from typing import Dict

import yfinance as yf

# %%
# import yfinance as yf
# import pandas as pd

# # Step 1: Download BTC and ETH data
# tickers = ['BTC-USD', 'ETH-USD']
# data = yf.download(tickers, start='2018-01-01', end='2025-01-01', group_by='ticker')

# # Step 2: Flatten MultiIndex columns
# data.columns = ['_'.join(col).strip() for col in data.columns.values]

# # Step 3: Separate into BTC and ETH DataFrames
# btc_data = data[[col for col in data.columns if 'BTC-USD' in col]].copy()
# eth_data = data[[col for col in data.columns if 'ETH-USD' in col]].copy()

# # Step 4: Clean up column names
# btc_data.columns = [col.replace('BTC-USD_', '') for col in btc_data.columns]
# eth_data.columns = [col.replace('ETH-USD_', '') for col in eth_data.columns]

# # Step 5: Add 'Date' column from index
# btc_data = btc_data.reset_index()
# eth_data = eth_data.reset_index()

# # Step 6: Save to CSV
# btc_data.to_csv('btc_data.csv', index=False)
# eth_data.to_csv('eth_data.csv', index=False)

# print("✅ BTC and ETH data saved to 'btc_data.csv' and 'eth_data.csv'")
# data.reset_index()

fees = 0.0006

# %%
BTC = pd.read_csv('btc_data.csv')
BTC.Date = pd.to_datetime(BTC.Date)
BTC
# Out:
#            Date          Open          High           Low         Close  \
# 0    2018-01-01  14112.200195  14112.200195  13154.700195  13657.200195
# 1    2018-01-02  13625.000000  15444.599609  13163.599609  14982.099609
# 2    2018-01-03  14978.200195  15572.799805  14844.500000  15201.000000
# 3    2018-01-04  15270.700195  15739.700195  14522.200195  15599.200195
# 4    2018-01-05  15477.200195  17705.199219  15202.799805  17429.500000
# ...         ...           ...           ...           ...           ...
# 2552 2024-12-27  95704.976562  97294.843750  93310.742188  94164.859375
# 2553 2024-12-28  94160.187500  95525.898438  94014.289062  95163.929688
# 2554 2024-12-29  95174.054688  95174.875000  92881.789062  93530.226562
# 2555 2024-12-30  93527.195312  94903.320312  91317.132812  92643.210938
# 2556 2024-12-31  92643.250000  96090.601562  91914.031250  93429.203125
#
#            Volume
# 0     10291200000
# 1     16846600192
# 2     16871900160
# 3     21783199744
# 4     23840899072
# ...           ...
# 2552  52419934565
# 2553  24107436185
# 2554  29635885267
# 2555  56188003691
# 2556  43625106843
#
# [2557 rows x 6 columns]

# %%
BTC_2020 = BTC[BTC.Date.dt.year == 2020].reset_index(drop=True)
BTC_2020
# Out:
#           Date          Open          High           Low         Close  \
# 0   2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 1   2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2   2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 3   2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# 4   2020-01-05   7410.451660   7544.497070   7400.535645   7411.317383
# ..         ...           ...           ...           ...           ...
# 361 2020-12-27  26439.373047  28288.839844  25922.769531  26272.294922
# 362 2020-12-28  26280.822266  27389.111328  26207.640625  27084.808594
# 363 2020-12-29  27081.810547  27370.720703  25987.298828  27362.437500
# 364 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 365 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
#
#           Volume
# 0    18565664997
# 1    20802083465
# 2    28111481032
# 3    18444271275
# 4    19725074095
# ..           ...
# 361  66479895605
# 362  49056742893
# 363  45265946774
# 364  51287442704
# 365  46754964848
#
# [366 rows x 6 columns]

# %%
sns.set(style="darkgrid")

# Create the line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x=BTC_2020.Date, y=BTC_2020.Close)

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('BTC Price Over Time')

# Rotate dates for readability if needed
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
BTC_2020
# Out:
#           Date          Open          High           Low         Close  \
# 0   2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 1   2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2   2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 3   2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# 4   2020-01-05   7410.451660   7544.497070   7400.535645   7411.317383
# ..         ...           ...           ...           ...           ...
# 361 2020-12-27  26439.373047  28288.839844  25922.769531  26272.294922
# 362 2020-12-28  26280.822266  27389.111328  26207.640625  27084.808594
# 363 2020-12-29  27081.810547  27370.720703  25987.298828  27362.437500
# 364 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 365 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
#
#           Volume
# 0    18565664997
# 1    20802083465
# 2    28111481032
# 3    18444271275
# 4    19725074095
# ..           ...
# 361  66479895605
# 362  49056742893
# 363  45265946774
# 364  51287442704
# 365  46754964848
#
# [366 rows x 6 columns]

# %%
netflow = pd.read_csv('netflow.csv')
netflow.Date = pd.to_datetime(netflow.Date, unit='ms').dt.date
netflow.Date = pd.to_datetime(netflow.Date)
netflow.dtypes
# Out:
# Date             datetime64[ns]
# NetflowVolume           float64
# dtype: object

# %%
netflow_2020 = netflow[netflow.Date.dt.year == 2020].reset_index(drop=True)

# %%
netflow_2020.drop_duplicates()
netflow_2020
# Out:
#           Date  NetflowVolume
# 0   2020-01-01    3364.505442
# 1   2020-01-01    1853.135410
# 2   2020-01-03    2897.774446
# 3   2020-01-04    5639.604847
# 4   2020-01-04    1102.205108
# ..         ...            ...
# 361 2020-12-27   11209.549776
# 362 2020-12-27   -4306.674691
# 363 2020-12-29   -9083.440257
# 364 2020-12-30   -5621.675550
# 365 2020-12-30   -6379.504261
#
# [366 rows x 2 columns]

# %%
data = BTC_2020.merge(netflow_2020.NetflowVolume, left_index=True, right_index=True)
data.dtypes
# Out:
# Date             datetime64[ns]
# Open                    float64
# High                    float64
# Low                     float64
# Close                   float64
# Volume                    int64
# NetflowVolume           float64
# dtype: object

# %%
data['price_change'] = data.Close.pct_change()

# %%
def z_score(data, window):
    roll = data.rolling(window, min_periods=1)
    mean = roll.mean()
    std = roll.std()

    return (mean - data)/ std

data['z_score'] = z_score(data.NetflowVolume, 14)

# %%
temp
# Out:
#           Date          Open          High           Low         Close  \
# 0   2020-01-01   7194.892090   7254.330566   7174.944336   7200.174316
# 1   2020-01-02   7202.551270   7212.155273   6935.270020   6985.470215
# 2   2020-01-03   6984.428711   7413.715332   6914.996094   7344.884277
# 3   2020-01-04   7345.375488   7427.385742   7309.514160   7410.656738
# 4   2020-01-05   7410.451660   7544.497070   7400.535645   7411.317383
# ..         ...           ...           ...           ...           ...
# 361 2020-12-27  26439.373047  28288.839844  25922.769531  26272.294922
# 362 2020-12-28  26280.822266  27389.111328  26207.640625  27084.808594
# 363 2020-12-29  27081.810547  27370.720703  25987.298828  27362.437500
# 364 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 365 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
#
#           Volume  NetflowVolume  price_change   z_score  positions  trades  \
# 0    18565664997    3364.505442           NaN       NaN          0     NaN
# 1    20802083465    1853.135410     -0.029819  0.707107          1     1.0
# 2    28111481032    2897.774446      0.051452 -0.248922          1     0.0
# 3    18444271275    5639.604847      0.008955 -1.377676          1     0.0
# 4    19725074095    1102.205108      0.000089  1.078143         -1     2.0
# ..           ...            ...           ...       ...        ...     ...
# 361  66479895605   11209.549776     -0.006231 -0.739269          1     0.0
# 362  49056742893   -4306.674691      0.030927  0.489482          1     0.0
# 363  45265946774   -9083.440257      0.010250  0.792293          1     0.0
# 364  51287442704   -5621.675550      0.054034  0.426221          1     0.0
# 365  46754964848   -6379.504261      0.005574  0.382697          1     0.0
#
#           pnl    equity
# 0         NaN       NaN
# 1   -0.000600 -0.000600
# 2    0.051452  0.050852
# 3    0.008955  0.059807
# 4   -0.001111  0.058696
# ..        ...       ...
# 361 -0.006231  0.255901
# 362  0.030927  0.286828
# 363  0.010250  0.297078
# 364  0.054034  0.351112
# 365  0.005574  0.356687
#
# [366 rows x 13 columns]

# %%
import math

def generate_position(data, threshold):
    z = data.z_score
    positions = [0]

    # high netflow volume = sell
    for score in z:
        if math.isnan(score):
            continue
        
        if score > threshold:
            position = -1
        else:
            position = 1
            
        positions.append(position)
        
    positions_series = pd.Series(positions)
    data['positions'] = positions_series  

    data['trades'] = abs(data.positions - data.positions.shift(1))

    return data

position_data = generate_position(data, 1)

# %%
def calc_metrics(data, fees, window):

    p_change = data.price_change
    position = data.positions.shift(1)
    trade = data.trades

    pnl = p_change*position-trade*fees
    data['pnl']= pnl

    data['equity'] = pnl.cumsum()

    avg_pnl = pnl.sum()/pnl.count()
    sharp_ratio = avg_pnl/pnl.std() * math.sqrt(365)
    
    trade_per_interval = data.trades.sum()/ data.trades.count()

    # drawdown = 
    
    roll_max = data.Close.cummax()
    # daily_drawdown = data.Close/roll_max - 1.0

    # data['drawdown'] = daily_drawdown
    # MDD = daily_drawdown.rolling(window, min_periods=1).min().iloc[-1]

    print(roll_max)
    return data, sharp_ratio, trade_per_interval, None

calc_data, sharp_ratio, trade_per_interval, MDD = calc_metrics(position_data, fees, 14)
calc_data.tail(30)
# Out:
# 0       7200.174316
# 1       7200.174316
# 2       7344.884277
# 3       7410.656738
# 4       7411.317383
#            ...
# 361    26437.037109
# 362    27084.808594
# 363    27362.437500
# 364    28840.953125
# 365    29001.720703
# Name: Close, Length: 366, dtype: float64
#           Date          Open          High           Low         Close  \
# 336 2020-12-02  18801.744141  19308.330078  18347.718750  19201.091797
# 337 2020-12-03  19205.925781  19566.191406  18925.785156  19445.398438
# 338 2020-12-04  19446.966797  19511.404297  18697.193359  18699.765625
# 339 2020-12-05  18698.384766  19160.449219  18590.193359  19154.230469
# 340 2020-12-06  19154.179688  19390.500000  18897.894531  19345.121094
# 341 2020-12-07  19343.128906  19411.828125  18931.142578  19191.630859
# 342 2020-12-08  19191.529297  19283.478516  18269.945312  18321.144531
# 343 2020-12-09  18320.884766  18626.292969  17935.546875  18553.916016
# 344 2020-12-10  18553.298828  18553.298828  17957.064453  18264.992188
# 345 2020-12-11  18263.929688  18268.453125  17619.533203  18058.904297
# 346 2020-12-12  18051.320312  18919.550781  18046.041016  18803.656250
# 347 2020-12-13  18806.765625  19381.535156  18734.332031  19142.382812
# 348 2020-12-14  19144.492188  19305.099609  19012.708984  19246.644531
# 349 2020-12-15  19246.919922  19525.007812  19079.841797  19417.076172
# 350 2020-12-16  19418.818359  21458.908203  19298.316406  21310.597656
# 351 2020-12-17  21308.351562  23642.660156  21234.675781  22805.162109
# 352 2020-12-18  22806.796875  23238.601562  22399.812500  23137.960938
# 353 2020-12-19  23132.865234  24085.855469  22826.472656  23869.832031
# 354 2020-12-20  23861.765625  24209.660156  23147.710938  23477.294922
# 355 2020-12-21  23474.455078  24059.982422  22159.367188  22803.082031
# 356 2020-12-22  22794.039062  23789.902344  22430.605469  23783.029297
# 357 2020-12-23  23781.974609  24024.490234  22802.646484  23241.345703
# 358 2020-12-24  23240.203125  23768.337891  22777.597656  23735.949219
# 359 2020-12-25  23733.570312  24710.101562  23463.673828  24664.791016
# 360 2020-12-26  24677.015625  26718.070312  24522.689453  26437.037109
# 361 2020-12-27  26439.373047  28288.839844  25922.769531  26272.294922
# 362 2020-12-28  26280.822266  27389.111328  26207.640625  27084.808594
# 363 2020-12-29  27081.810547  27370.720703  25987.298828  27362.437500
# 364 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 365 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
#
#           Volume  NetflowVolume  price_change   z_score  positions  trades  \
# 336  37387697139   -1075.068203      0.021172  0.559054          1     0.0
# 337  31930317405    1891.892343      0.012724  0.034382          1     0.0
# 338  33872388058   -4916.620037     -0.038345  1.195275         -1     2.0
# 339  27242455064    1882.086944      0.024303 -0.091893          1     2.0
# 340  25293775714   -3167.739301      0.009966  0.773418          1     0.0
# 341  26896357742    3295.336750     -0.007934 -0.426544          1     0.0
# 342  31692288756   -9026.482632     -0.045358  1.553356         -1     2.0
# 343  34420373071   -3119.058355      0.012705  0.483306          1     2.0
# 344  25547132265   -6030.146253     -0.015572  1.036812         -1     2.0
# 345  27919640985    7410.764830     -0.011283 -1.780873          1     2.0
# 346  21752580802   10218.392800      0.041240 -1.868089          1     0.0
# 347  25450468637    7850.793923      0.018014 -1.220408          1     0.0
# 348  22473997681    8985.573140      0.005447 -1.272031          1     0.0
# 349  26741982541    4404.651264      0.008855 -0.507608          1     0.0
# 350  44409011479    8991.679919      0.097518 -1.094746          1     0.0
# 351  71378606374   17513.508763      0.070132 -1.895903          1     0.0
# 352  40387896275    4539.358469      0.014593 -0.097171          1     0.0
# 353  38487546580    6766.272000      0.031631 -0.357011          1     0.0
# 354  37844228422   -3696.749664     -0.016445  1.080211         -1     2.0
# 355  45852713981    5436.057104     -0.028718 -0.155882          1     2.0
# 356  44171632681  -16570.120510      0.042974  2.390619         -1     2.0
# 357  51146161904  -28551.303330     -0.022776  2.528598         -1     0.0
# 358  41080759713    5711.864851      0.021281 -0.246432          1     2.0
# 359  42068395846    8211.484712      0.039132 -0.451195          1     0.0
# 360  48332647295    1151.441550      0.071853  0.089207          1     0.0
# 361  66479895605   11209.549776     -0.006231 -0.739269          1     0.0
# 362  49056742893   -4306.674691      0.030927  0.489482          1     0.0
# 363  45265946774   -9083.440257      0.010250  0.792293          1     0.0
# 364  51287442704   -5621.675550      0.054034  0.426221          1     0.0
# 365  46754964848   -6379.504261      0.005574  0.382697          1     0.0
#
#           pnl    equity  drawdown
# 336  0.021172 -0.070781 -0.021642
# 337  0.012724 -0.058057 -0.009194
# 338 -0.039545 -0.097602 -0.047186
# 339 -0.025503 -0.123106 -0.024030
# 340  0.009966 -0.113140 -0.014303
# 341 -0.007934 -0.121074 -0.022124
# 342 -0.046558 -0.167632 -0.066478
# 343 -0.013905 -0.181537 -0.054618
# 344 -0.016772 -0.198309 -0.069339
# 345  0.010083 -0.188226 -0.079840
# 346  0.041240 -0.146985 -0.041893
# 347  0.018014 -0.128972 -0.024634
# 348  0.005447 -0.123525 -0.010221
# 349  0.008855 -0.114670 -0.001457
# 350  0.097518 -0.017151  0.000000
# 351  0.070132  0.052981  0.000000
# 352  0.014593  0.067574  0.000000
# 353  0.031631  0.099205  0.000000
# 354 -0.017645  0.081560 -0.016445
# 355  0.027518  0.109078 -0.044690
# 356  0.041774  0.150852 -0.003637
# 357  0.022776  0.173628 -0.026330
# 358 -0.022481  0.151147 -0.005609
# 359  0.039132  0.190279  0.000000
# 360  0.071853  0.262132  0.000000
# 361 -0.006231  0.255901 -0.006231
# 362  0.030927  0.286828  0.000000
# 363  0.010250  0.297078  0.000000
# 364  0.054034  0.351112  0.000000
# 365  0.005574  0.356687  0.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="darkgrid")

# Create figure and primary axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot BTC Price (Left Y-axis)
color = 'tab:blue'
sns.lineplot(x=BTC_2020.Date, y=BTC_2020.Close, ax=ax1, color=color, label='BTC Price')
ax1.set_xlabel('Date')
ax1.set_ylabel('BTC Price (USD)', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create secondary axis for Equity
ax2 = ax1.twinx()
color = 'tab:red'
sns.lineplot(x=calc_data.Date, y=calc_data.equity, ax=ax2, color=color, label='Strategy Equity')
ax2.set_ylabel('Equity (Scaled)', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Add title and format
plt.title('BTC Price vs. Strategy Performance (2020)')
fig.legend(loc="upper left", bbox_to_anchor=(0.15, 0.9))

# Rotate dates and adjust layout
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
